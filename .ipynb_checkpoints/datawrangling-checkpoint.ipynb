# %%
import glob
import pandas as pd

def format_data(data):
    temp = data[['0','1','name']].dropna()
    df = temp.pivot_table(index='name',columns='0', values='1', aggfunc='first')
    df = temp.pivot_table(index='name',columns='0', values='1', aggfunc='first')
    df['% ch'] = df['% ch'].apply(lambda x:float(x)/100 if x!= '-' else 0)
    df['% ch 1-mth'] = df['% ch 1-mth'].apply(lambda x:float(x)/100 if x!= '-' else 0)
    df['% ch 12-mth'] =df['% ch 12-mth'].apply(lambda x:float(x)/100 if x!= '-' else 0)
    df['% ch week'] = df['% ch week'].apply(lambda x:float(x)/100 if x!= '-' else 0)
    df.drop(['52 week H/L','AUDITOR','CHM','COMP SEC','E-MAIL','REGD OFF', 'TELEPHONE', 'TR AGENT'], axis=1, inplace=True)
    df['52weekHigh'] = df['52weekHigh'].apply(lambda x:float(x.replace(',','')) if x!= '-' else 0)
    df['52weekLow'] = df['52weekLow'].apply(lambda x:float(x.replace(',','')) if x!= '-' else 0)
    df['ADR/GDR'] = df['ADR/GDR'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['DIV YIELD (%)'] = df['DIV YIELD (%)'].apply(lambda x:float(x) if x!= '-' and x!='\xa0-' else 0)
    df['EPS\xa0(TTM)'] = df['EPS\xa0(TTM)'].apply(lambda x:float(x) if x!= '-' and x!='\xa0-' else 0)
    df['FIIs'] = df['FIIs'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['FV (Rs)'] = df['FV (Rs)'].apply(lambda x:float(x) if x!= '-' else 0)
    df['Foreign collaborators'] = df['Foreign collaborators'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['Free float'] = df['Free float'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['Indian Promoters'] = df['Indian Promoters'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['Indian inst/Mut Fund'] = df['Indian inst/Mut Fund'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['Mkt Cap'] = df['Mkt Cap'].apply(lambda x:float(x)*1000000 if x!= '-' else 0)
    df['No. of shares'] = df['No. of shares'].apply(lambda x:float(x)*1000000 if x!= '-' else 0)
    df['P/CF'] = df['P/CF'].apply(lambda x:float(x) if x!= '-' else 0)
    df['P/E'] = df['P/E'].apply(lambda x:float(x) if x!= '-' else 0)
    df['Pledged promoter(s) holding'] = df['Pledged promoter(s) holding'].apply(lambda x:float(x.replace('%',''))/100 if x!= '-' else 0)
    df['Price'] = df['Price'].apply(lambda x:float(x.replace(',','')) if x!= '-' else 0)
    df["SECTOR"] = df["SECTOR"].astype('category')
    df['SECTOR'] = df["SECTOR"].cat.codes
    df['Shareholders'] = df['Shareholders'].apply(lambda x:float(x) if x!= '-' else 0)
    df['Vol'] = df['Vol'].apply(lambda x:float(x)*1000 if x!= '-' else 0)
    df['YEAR OF INC'] = df['YEAR OF INC'].apply(lambda x:float(x) if x!= '-' else 0 )
    df.columns=list(df.columns)
    df.index = list(df.index)    
    return df

# %%
glued_data = pd.DataFrame()
for file_name in glob.glob('data/main/'+'*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)
    
df =format_data(glued_data)
df.to_pickle('main_df')

# %%
df.columns
# Out:
# Index(['% ch', '% ch 1-mth', '% ch 12-mth', '% ch week', '52weekHigh',
#        '52weekLow', 'ADR/GDR', 'BSE CODE', 'DIV YIELD (%)', 'EPS (TTM)',
#        'FIIs', 'FV (Rs)', 'Foreign collaborators', 'Free float',
#        'Indian Promoters', 'Indian inst/Mut Fund', 'Mkt Cap', 'No. of shares',
#        'P/CF', 'P/E', 'Pledged promoter(s) holding', 'Price', 'SECTOR',
#        'Shareholders', 'Vol', 'YEAR OF INC'],
#       dtype='object')

# %%
interest_list = ['BSE CODE','Price','52weekHigh', '52weekLow', 'P/E', 'P/CF', 'EPS\xa0(TTM)', 'Mkt Cap', 'DIV YIELD (%)','Vol','SECTOR']
df[df['SECTOR']==12].sort_values(by='P/E', ascending=False)[interest_list]
# Out:
#        BSE CODE   Price 52weekHigh 52weekLow     P/E   P/CF EPS (TTM)  \
# RINF     523445   425.6      479.7     164.0    81.1   29.2       5.3
# GPL      533150   867.0    1,188.0     506.0    71.3   68.2      12.2
# PONA     532486   146.9      181.0      46.8     6.4    4.3      22.8
# NRCN     500294    36.2       70.9      15.9     6.2    2.6       5.8
# IRB      532947   129.1      138.8      46.0     5.8    3.1      22.2
# SHPRC    513349    90.5      155.5      53.0     5.6    4.1      16.0
# SXCN     523838    34.4       64.1      16.5     5.5    0.6       6.2
# PIRLS    503101    57.2      110.9      38.0     4.7    6.3      12.1
# ASHBL    533271    72.6      127.9      37.0     3.5    6.2      20.7
# PATEL    531120    14.3       21.9       7.2     3.0    0.5       4.8
# PHNXM    503100   665.2      979.5     466.3    27.1   23.5      24.6
# OMAXE    532880    73.6      222.2      59.6    26.9   23.4       2.7
# IBRL     532832    67.6      113.0      36.9    23.4    5.5       2.9
# AHLU     532811   255.0      369.3     136.1    20.9   11.8      12.2
# INET     512179   258.9      487.4     145.0    20.4   13.4      12.7
# BRGD     532929   167.8      255.0      90.7    20.3    5.4       8.3
# SBPR     500402    11.5       15.5       5.0     2.9    0.8       3.9
# HDIL     532873     5.2        6.8       1.2     2.3    2.0       2.2
# ANRI     515055    37.4       40.8      13.4    19.9   14.0       1.9
# PSPR     540544   447.5      576.9     233.8    15.9   14.2      28.2
# HYDI     509675  1574.4    1,670.0     497.2    14.6    6.9     108.1
# KOLTE    532924   179.9      288.0     103.1    13.7   11.9      13.2
# PURVA    532891    50.9       79.6      28.7    13.2    9.3       3.9
# SOBHA    532784   259.2      550.0     117.9    12.9    7.1      20.1
# ENGS     532178    71.9      123.0      49.9    11.3   12.3       6.4
# JKIL     532940   119.7      179.8      65.2     1.8    1.4      65.1
# GESCO    532313   283.1      454.2     171.2    -6.8   23.3     -41.5
# BLKS     532719     7.1       12.1       3.4    -6.0    3.9      -1.2
# AIPL     533163    13.8       29.8       9.1    -5.4    2.0      -2.5
# ANSAL    500013     4.6        6.9       3.4    -4.3   -0.6      -1.1
# ASHG     523716    82.1      125.0      39.0   -27.8   38.3      -3.0
# DLFL     532868   160.8      266.7     114.5   -15.9    5.9     -10.1
# PREN     531746     6.5        8.6       3.6  -110.8   -4.6      -0.1
# AKRUTI   532799    12.2       18.8       7.1    -1.9  -10.3      -6.6
# MRGC     530543     7.4       13.0       5.7    -1.7   -0.7      -4.3
# NOTO     532481     3.3        6.2       2.4    -1.6    8.3      -2.1
# PARS     532780     3.3        3.9       1.2    -1.6   -0.4      -2.1
# HCNS     500185     6.3       13.3       3.6    -1.3  -39.1      -4.8
# JPAS     532532     4.1        4.8       1.1    -1.1   -0.5      -3.7
# ANSH     507828     4.7        9.2       2.6    -1.1  -12.8      -4.3
# MPRJ     531497     2.6        5.4       1.5    -0.7   -0.1      -3.6
# UNTE     507878     1.8        3.8       0.4    -0.7   -0.5      -2.6
# DBRL     533160     7.5       12.5       3.6    -0.5   -0.6     -14.6
# BSEL     532123     1.2        1.6       0.7    -0.4   -0.5      -2.9
# MRJE     503031     4.7        6.4       2.2    -0.2   -0.2     -23.4
# CCON     532813     2.7        5.5       1.9    -0.1   -0.0     -26.4
# UNFRA    532746     0.9        0.9       0.3    -0.0    0.2    -150.3
#
#          Mkt Cap DIV YIELD (%)      Vol  SECTOR
# RINF      6427.0           0.7      0.5      12
# GPL     172836.0             -      1.1      12
# PONA      4553.0           0.4      5.1      12
# NRCN     20125.0           4.5     60.5      12
# IRB      42891.0           2.0     29.4      12
# SHPRC     3211.0           3.6      1.2      12
# SXCN      1702.0           1.7     10.8      12
# PIRLS     1624.0           1.4      2.4      12
# ASHBL    13578.0             -     50.5      12
# PATEL     1097.0             -      2.2      12
# PHNXM    96387.0           0.4  15392.0      12
# OMAXE    13461.0           1.0      0.0      12
# IBRL     28729.0             -     11.8      12
# AHLU     17082.0           0.1      0.8      12
# INET     32611.0           0.6      0.8      12
# BRGD     22844.0           1.2      4.2      12
# SBPR       421.0             -      0.5      12
# HDIL      2183.0             -    498.0      12
# ANRI     11023.0           0.6     23.8      12
# PSPR     16110.0           1.1      0.8      12
# HYDI     11761.0           1.6      2.5      12
# KOLTE    13631.0           0.8      9.1      12
# PURVA    12071.0           2.0      8.8      12
# SOBHA    25417.0           2.6      0.9      12
# ENGS     48455.0           5.2      7.7      12
# JKIL      3858.0           4.4      1.4      12
# GESCO    11610.0           2.7      0.1      12
# BLKS      1448.0             -      0.0      12
# AIPL       205.0             -      2.6      12
# ANSAL      730.0             -     33.2      12
# ASHG      8398.0           0.3      3.4      12
# DLFL    286534.0           1.3     50.1      12
# PREN       451.0             -      8.0      12
# AKRUTI     889.0             -      2.1      12
# MRGC       281.0             -      0.0      12
# NOTO       614.0             -     49.8      12
# PARS      1445.0             -     35.6      12
# HCNS      4870.0             -     17.3      12
# JPAS     10022.0             -    168.1      12
# ANSH       282.0             -      0.5      12
# MPRJ       195.0             -     17.0      12
# UNTE      4683.0             -     48.7      12
# DBRL      1815.0             -      1.7      12
# BSEL        97.0             -      4.6      12
# MRJE      1315.0             -     42.0      12
# CCON        67.0             -     17.8      12
# UNFRA       68.0             -      0.2      12

# %%
# Out:
# name
# 20MIC    1987.0
# ABAN     1970.0
# ABB      1949.0
# ABBA     1992.0
# ABHI     1988.0
#           ...
# YES      1998.0
# ZEE      1992.0
# ZFSG     1980.0
# ZNEWS    2006.0
# ZUAR     1967.0
# Name: YEAR OF INC, Length: 690, dtype: float64

# %%
# Out:
# 690
